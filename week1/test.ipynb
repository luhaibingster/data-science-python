# %%
pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6116 sha256=4eb7b4975c51b064e821268bf4366a8d4e0a02bf5fd5a6665fed90f7deef4f0f
#   Stored in directory: c:\users\hlu\appdata\local\pip\cache\wheels\e3\43\83\0f6e317d0698ac38ee6a5b6e214019c167057916a11bad91ab
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
#
#    ---------------------------------------- 2/2 [feedparser]
#
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import feedparser
from urllib.parse import quote_plus

def google_news(company: str, max_results: int = 10):
    q = quote_plus(company)
    url = f"https://news.google.com/rss/search?q={q}&hl=en-US&gl=US&ceid=US:en"
    feed = feedparser.parse(url)

    results = []
    for entry in feed.entries[:max_results]:
        results.append({
            "title": entry.title,
            "link": entry.link,
            "published": getattr(entry, "published", ""),
            "source": getattr(entry, "source", {}).get("title", "") if hasattr(entry, "source") else ""
        })
    return results

google_news("meta", 10)
# Out:
# [{'title': 'Nvidia and Meta expand GPU team up with millions of additional AI chips - Yahoo Finance',
#   'link': 'https://news.google.?oc=5',
#   'published': 'Wed, 18 Feb 2026 14:40:11 GMT',
#   'source': 'Yahoo Finance'},
#  {'title': 'Meta CEO Mark Zuckerberg to face jury in landmark social media addiction trial - NPR',
#   'link': 'https://news.google.com/rss/articles/CBMijAFBVV95cUxPZ1oxcUw1VHdVc205OXNzcTZMcW5NV3h6ZUdQblVJTTBrY3dxT2RXcjZHV1VGZ2FTUUZwQmt5SG42Mkt2dHJCNHNEcm5XVmZSLXE3al9Yd2ZVVkRKVU1tRHUxN1pFYjl4V01XY0xudUcwZ0JCR0FjX2lOaDJ2d1JwZXJGcTQ0WDhrOW01MA?oc=5',
#   'published': 'Wed, 18 Feb 2026 10:00:00 GMT',
#   'source': 'NPR'},
#  {'title': 'Meta Begins $65 Million Election Push to Advance A.I. Agenda - The New York Times',
#   'link': 'https://news.google.com/rss/articles/CBMihAFBVV95cUxOSHJLYXROZnBmdEtPakM2ZFFhT1dWam5TMU9Rd0k0aU9aY0RRUEROQ2txMlR5bDFFSHh5QnBwSVM4QjJ4NXZTeDNTSTlDelFvaWsxYWo5cldHWG5uaDI0OVptbWZpd1Z5dzZfQWdqWXdkOVJkUElCNzlJeWNFLU9rVXdSNlE?oc=5',
#   'published': 'Wed, 18 Feb 2026 16:01:07 GMT',
#   'source': 'The New York Times'},
#  {'title': 'Meta and Other Tech Firms Put Restrictions on Use of OpenClaw Over Security Fears - WIRED',
#   'link': 'https://news.google.com/rss/articles/CBMikwFBVV95cUxPakFmbFRqY3VmODljR2xMdlYwT1ZqcW40d0lFa1lUdXlEUkNyWWdMYTBvNkltS1cwMW5SZHJPNzQzaUtfNEF3aVBsaVVpSzdlNHFraWh1ZzdFLVFVVGZPOUF3bTFJSmlpRGJxUWxhcFpVTkV2SUY1UzdFb05lZzNmN1REYzh3MzE3bV9Tbzk5V29HaWs?oc=5',
#   'published': 'Tue, 17 Feb 2026 20:10:00 GMT',
#   'source': 'WIRED'},
#  {'title': 'Meta wins patent for AI that could post for dead social media users - Mashable',
#   'link': 'https://news.google.com/rss/articles/CBMiZ0FVX3lxTE8zdXBTRl80QzdZM1M0RjcxbUVJaW5BbDZYNUFTSGVwckNEdVNJTVZDeFhVallMcURDWDNqeFNOMEpGVkhERlhPWjU4dnR2eDhIVEtnckZkTjZaT0NoTW1Kbi1XZG1sLVE?oc=5',
#   'published': 'Wed, 18 Feb 2026 01:35:17 GMT',
#   'source': 'Mashable'},
#  {'title': 'Move over Meta: Apple smart glasses are coming - Macworld',
#   'link': 'https://news.google.com/rss/articles/CBMilgFBVV95cUxNR29nbmFLbUFadFl1WmxYTkE0RVFqdVNOY2JjVTdHV241RHlrZkpxNGlfVGozeVpESGJ4eWRRUWh5bnlfalQ0UW01eW9ZWkRERnNFUkhjcFlPNlFYUU1KVXJDVzF1bFFEaWVGZXJZdERuRWxlZUtRLUx4dDFMbDBGTkFfc0RsMFpwdWEycWFFdWJzXzRvWkE?oc=5',
#   'published': 'Tue, 17 Feb 2026 19:57:00 GMT',
#   'source': 'Macworld'},
#  {'title': 'Spain Orders Criminal Investigation Into X, Meta, and TikTok Over Alleged AI-Generated Child Sexual Abuse Material - Time Magazine',
#   'link': 'https://news.google.com/rss/articles/CBMiqwFBVV95cUxPRFQ3V2JYTmppdHBCUkpXWDFxRkpzbm16Y0ZXTHFJWHZDcHpaVGs3QWtKbzdoU1RkNC1oeFdDcFhzOVZDaXZCcXNSZlFueFlqVmEtQTZsVUZ4VlRjTWg4UmRyclEySWI3dFhMX1h2cEtDTkZNQ24ydkJvVVZQNEJDakdMT3lnRkRpcDU3WFE0YWRJUVpxMVlSckY5MzJCaWFFWGp6VHlHM1lqTlE?oc=5',
#   'published': 'Tue, 17 Feb 2026 22:44:43 GMT',
#   'source': 'Time Magazine'},
#  {'title': "Meta's own research found parental supervision doesn't really help curb teens' compulsive social media use - TechCrunch",
#   'link': 'https://news.google.?oc=5',
#   'published': 'Tue, 17 Feb 2026 20:45:33 GMT',
#   'source': 'TechCrunch'},
#  {'title': 'Meta Platforms: Why Strong Money Loves It - Seeking Alpha',
#   'link': 'https://news.google.com/rss/articles/CBMiiAFBVV95cUxQUW9ObnRtUjROaU9uZG1tMTdjdEUweFR1M01Wcml3M0JKQ1U2Zko5d2tuY1lYZXpvcmY4RTE1VDRGN2k4MzNBOGhIX1g5Z1k2RThRZ2ZyQzliRlR4S1A1VC15SDdrV3YxSWlvVEh2MHZjdmVZSWsyQ2xQRW9fay11S1Rtb2M3eWRK?oc=5',
#   'published': 'Wed, 18 Feb 2026 06:23:43 GMT',
#   'source': 'Seeking Alpha'},
#  {'title': 'A Gen Zer took a 6-figure job at Meta to rebuild her savings. Then she quit and returned to her dream. - Business Insider',
#   'link': 'https://news.google.com/rss/articles/CBMimgFBVV95cUxQTzYzdGFibWpLXzZjSGFHYWlOeS1Haks2NExyVEJuc1lFTURBYTl6OWd5RFVhV1dkZ1ZvcXJCbnVZOGlvbmtsdXBLMk1ZZHRvQ2xRWlR1bGZNQV9pOHpDRldLT1pWTlVYVkxDWThYR29OdzVtcGNqUlR4RUlSalIzamdYZDdKdFl2VDJQWUNsS3J3MnFlMXdHemRR?oc=5',
#   'published': 'Mon, 16 Feb 2026 07:47:00 GMT',
#   'source': 'Business Insider'}]
